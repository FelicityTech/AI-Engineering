# %% [markdown]
# #### Merge Layers

# %%
from tensorflow.keras.layers import Input, Add

in_tensor_1 = Input((1,))
in_tensor_2 = Input((1,))
added = Add()([in_tensor_1, in_tensor_2])

# %% [markdown]
# #### Create model

# %%
from tensorflow.keras import Model

model = Model(inputs=[in_tensor_1, in_tensor_2], outputs=added)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1)         │          0 │ input_layer[0][0… │
# │                     │                   │            │ input_layer_1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer='adam', loss='mean_absolute_error')

# %%
# Import the Subtract layer from tensorflow.keras
from tensorflow.keras.layers import Subtract

# Create a subtract layer using the inputs from the previous exercise
score_diff = Subtract()([team_1_strength, team_2_strength])

# %%
# Imports
from tensorflow.keras.layers import Subtract
from tensorflow.keras.models import Model

# Subtraction layer from previous exercise
score_diff = Subtract()([team_1_strength, team_2_strength])

# Create the model
model = Model([team_in_1, team_in_2], score_diff)

# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error')

# %% [markdown]
# #### Fit with Multiple input

# %%
model.fit([data_1, data_2], targets)

# %% [markdown]
# #### Predict with multiple inputs

# %%
import numpy as np

model.predict([np.array([[1]]), np.array([[2]])])
np.array([[[3.]]], dtype=np.float32)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# array([[[3.]]], dtype=float32)

# %%
model.predict([np.array([[42]]), np.array([[119]])])
np.array([[[161.]]], dtype=np.float32)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# array([[[161.]]], dtype=float32)

# %% [markdown]
# #### Evaluate with multiple inputs

# %%
model.evaluate([np.array([[-1]]), np.array([[-2]])], np.array([[[-3.]]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step - loss: 0.0000e+00
# 0.0

# %%
# Get the team_1 column from the regular season data
import numpy as np
input_1 = games_season['team_1']

# Get the team_2 column from the regular season data
input_2 = games_season['team_2']

# Fit the model to input 1 and 2, using score diff as a target
model.fit([np.array(input_1), np.array(input_2)],
          games_season['score_diff'],
          epochs=1,
          batch_size=2048,
          validation_split=0.1,
          verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Get the team_1 column from the regular season data
#       2 import numpy as np
# ----> 3 input_1 = games_season['team_1']
#       5 # Get the team_2 column from the regular season data
#       6 input_2 = games_season['team_2']
#
# NameError: name 'games_season' is not defined

# %%
# Get team_1 from the tournament data
input_1 = games_tourney['team_1']

# Get team_2 from the tournament data
input_2 = games_tourney['team_2']

# Evaluate the model using these inputs
print(model.evaluate([input_1, input_2], games_tourney['score_diff'], verbose=False))
