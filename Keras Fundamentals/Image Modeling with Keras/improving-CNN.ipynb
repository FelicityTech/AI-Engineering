# %% [markdown]
# # Tracking learning

# %%
training = model.fit(train_data, train_labels, epoch)
import matplotlib.pyplot as plt
plt.plot(training.history['loss'])
plt.plot(training.history['val_loss'])

# %% [markdown]
# ### Storing the optimal parameters

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("model_weights.hdf5", monitor='val_loss', save_best_only=True)

# Store in a list to be used during training
callbacks_list = [checkpoint]

# Fit the model on a training set, using checkpoint as a callback

model.fit(train_data, train_labels, epochs=epoch, callbacks=callbacks_list, validation_split=0.2)

# %% [markdown]
# ### Loading stored parameters

# %%
model.load_weights("model_weights.hdf5")
model.evaluate(test_data, test_labels)
array([2, 2, 1, 2, 0, 1, 2, 0, 0, 1])

# %% [markdown]
# ### Ploting learning curve

# %%
import matplotlib.pyplot as plt

# Train the model and store the training object
training = model.fit(train_data, train_labels, validation_split=0.2, epochs=3, batch_size=10)

# Extract the history from the training object
history = training.history

# Plot the training loss 
plt.plot(history['loss'])
# Plot the validation loss
plt.plot(history['val_loss'])

# Show the figure
plt.show()

# %%
# Load the weights from file
model.load_weights('weights.hdf5')

# Predict from the first three images in the test data
model.predict(test_data[:3])

# %% [markdown]
# ### Neural network Regularization
# - Dropout in Keras

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, Dropout
model = Sequential()
model.add(Conv2D(5, kernel_size=3, activation='relu', input_shape=(28, 28, 1)))
model.add(Dropout(0.25))
model.add(Conv2D(15, kernel_size=3, activation='relu'))
model.add9(Flatten())
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# - Batch normalization
#   - Rescale the output

# %% [markdown]
# ### Batch Normalization in Keras

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, Dropout, BatchNormalization
model = Sequential()

model.add(Conv2D(5, kernel_size=3, activation='relu', input_shape=(28, 28, 1)))
model.add(BatchNormalization())
model.add(Conv2D(15, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(3, activation='softmax'))

# %%
# Add a convolutional layer
model.add(Conv2D(15, kernel_size=2, activation='relu', 
                 input_shape=(img_rows, img_cols, 1)))

# Add a dropout layer
model.add(Dropout(0.2))

# Add another convolutional layer
model.add(Conv2D(5, kernel_size=2, activation='relu'))

# Flatten and feed to output layer
model.add(Flatten())
model.add(Dense(3, activation='softmax'))

# %%
# Add a convolutional layer
model.add(Conv2D(15, kernel_size=2, activation='relu', input_shape=(img_rows, img_cols, 1)))


# Add batch normalization layer
model.add(BatchNormalization())

# Add another convolutional layer
model.add(Conv2D(5, kernel_size=2, activation='relu'))

# Flatten and feed to output layer
model.add(Flatten())
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ### Interpreting the model
# - Selecting layers

# %%
model.layers

# %% [markdown]
# - Getting model weights

# %%
conv1 = model.layers[0]
conv1_weights = conv1.get_weights()
len(conv1_weights)

# %%
kernels1 = conv1_weights[0]
kernels1.shape

# %%
kernel_1 = kernels1[:, :, 0, 0]
kernel_1.shape

# %% [markdown]
# - Visualizing the kernel

# %%
plt.imshow(kernel_1)

# %% [markdown]
# - Visualizing the kernel responses

# %%
test_image = test_data[3, :, :, 0]
plt.imshow(test_image)

# %%
filtered_image = convolution(test_image, kernel_1)
plt.imshow(filtered_image)

test_image = test_data[4, :, :, 1]
plt.imshow(test_image)

# %%
filtered_image = convolution(test_image, kernel_1)
plt.imshow(filtered_image)

# %%
# Load the weights into the model
model.load_weights('weights.hdf5')

# Get the first convolutional layer from the model
c1 = model.layers[0]

# Get the weights of the first convolutional layer
weights1 = c1.get_weights()

# Pull out the first channel of the first kernel in the first layer
kernel = weights1[0][:, :,0, 0]
print(kernel)
