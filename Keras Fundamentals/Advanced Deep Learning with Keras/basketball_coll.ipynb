# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
game_season = pd.read_csv('games_season.csv')
# Display the first few rows of the dataset
print(game_season.head())
# Out:
#    season  team_1  team_2  home  score_diff  score_1  score_2  won
# 0    1985    3745    6664     0          17       81       64    1
# 1    1985     126    7493     1           7       77       70    1
# 2    1985     288    3593     1           7       63       56    1
# 3    1985    1846    9881     1          16       70       54    1
# 4    1985    2675   10298     1          12       86       74    1

# %%
games_tourney = pd.read_csv('games_tourney.csv')
print(games_tourney.head())
# Out:
#    season  team_1  team_2  home  seed_diff  score_diff  score_1  score_2  won
# 0    1985     288      73     0         -3          -9       41       50    0
# 1    1985    5929      73     0          4           6       61       55    1
# 2    1985    9884      73     0          5          -4       59       63    0
# 3    1985      73     288     0          3           9       50       41    1
# 4    1985    3920     410     0          1          -9       54       63    0

# %% [markdown]
# #### Input

# %%
from tensorflow.keras.layers import Input
input_tensor = Input(shape=(1,))
print(input_tensor)
# Out:
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_2>

# %% [markdown]
# #### Outputs

# %%
from tensorflow.keras.layers import Dense
output_layer = Dense(1)(input_tensor)
print(output_layer)
# Out:
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_3>

# %% [markdown]
# ### Connecting inputs to outputs

# %%
from tensorflow.keras.layers import Input, Dense
input_tensor = Input(shape=(1,))
output_layer = Dense(1)
output_tensor = output_layer(input_tensor)
print(output_tensor)
# Out:
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_5>

# %% [markdown]
# ### Exercise

# %%
# Load layers
from tensorflow.keras.layers import Input, Dense

# Input layer
input_tensor = Input(shape=(1,))

# Dense layer
output_layer = Dense(1)

# Connect the dense layer to the input_tensor
output_tensor = output_layer(input_tensor)

# %%
# Load layers
from tensorflow.keras.layers import Input, Dense

# Input layer
input_tensor = Input(shape=(1,))

# Create a dense layer and connect the dense layer to the input_tensor in one step
# Note that we did this in 2 steps in the previous exercise, but are doing it in one step now
output_tensor = Dense(1)(input_tensor)

# %% [markdown]
# #### Keras Models

# %%
from tensorflow.keras.layers import Input, Dense
# Input layer
input_tensor = Input(shape=(1,))
# Create a dense layer and connect the dense layer to the input_tensor in one step
output_tensor = Dense(1)(input_tensor)
print(output_tensor)
# Out:
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_1>

# %%
from tensorflow.keras.models import Model
# Create a model that connects the input_tensor to the output_tensor
model = Model(inputs=input_tensor, outputs=output_tensor)
# compile the model
model.compile(optimizer='adam', loss='mae')

# summarize the model
print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
pip install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pydot
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from pydot) (3.2.0)
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Installing collected packages: pydot
# Successfully installed pydot-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.utils import plot_model
input_tensor = Input(shape=(1,))
output_layer = Dense(1, name="Predicted-Score-Diff")
output_tensor = output_layer(input_tensor)
model = Model(inputs=input_tensor, outputs=output_tensor)
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

from matplotlib import pyplot as plt
img = plt.imread('model_plot.png')
plt.imshow(img)
plt.show()
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
#       8 from matplotlib import pyplot as plt
# ----> 9 img = plt.imread('model_plot.png')
#      10 plt.imshow(img)
#      11 plt.show()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2613, in imread(fname, format)
#    2609 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2610 def imread(
#    2611         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2612 ) -> np.ndarray:
# -> 2613     return matplotlib.image.imread(fname, format)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\image.py:1502, in imread(fname, format)
#    1495 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1496     # Pillow doesn't handle URLs directly.
#    1497     raise ValueError(
#    1498         "Please open the URL for reading and pass the "
#    1499         "result to Pillow, e.g. with "
#    1500         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501         )
# -> 1502 with img_open(fname) as image:
#    1503     return (_pil_png_to_float_array(image)
#    1504             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1505             pil_to_array(image))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\PIL\ImageFile.py:132, in ImageFile.__init__(self, fp, filename)
#     128 self.decodermaxblock = MAXBLOCK
#     130 if is_path(fp):
#     131     # filename
# --> 132     self.fp = open(fp, "rb")
#     133     self.filename = os.fspath(fp)
#     134     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_plot.png'

# %% [markdown]
# ### Exercise

# %%
# Input/dense/output layers
from tensorflow.keras.layers import Input, Dense
input_tensor = Input(shape=(1,))
output_tensor = Dense(1)(input_tensor)

# Build the model
from tensorflow.keras.models import Model
model = Model(input_tensor, output_tensor)

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error')

# %%
# Import the plotting function
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# Summarize the model
model.summary()

# Plot the model
plot_model(model, to_file='image.png')

# Display the image
data = plt.imread('image.png')
plt.imshow(data)
plt.show()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %% [markdown]
# ####
